# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency
import numpy as np
from IPython.display import display
df = pd.read_csv('dataset/survey_results_public.csv', sep=',')
display(df.info())
display(df.describe())
# Out:
# C:\Users\tomma\AppData\Local\Temp\ipykernel_9224\3044601474.py:7: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('dataset/survey_results_public.csv', sep=',')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98855 entries, 0 to 98854
# Columns: 129 entries, Respondent to SurveyEasy
# dtypes: float64(41), int64(1), object(87)
# memory usage: 97.3+ MB
# None
#           Respondent    AssessJob1    AssessJob2    AssessJob3    AssessJob4  \
# count   98855.000000  66985.000000  66985.000000  66985.000000  66985.000000
# mean    50822.971635      6.397089      6.673524      5.906875      4.065791
# std     29321.650410      2.788428      2.531202      2.642734      2.541196
# min         1.000000      1.000000      1.000000      1.000000      1.000000
# 25%     25443.500000      4.000000      5.000000      4.000000      2.000000
# 50%     50823.000000      7.000000      7.000000      6.000000      4.000000
# 75%     76219.500000      9.000000      9.000000      8.000000      6.000000
# max    101592.000000     10.000000     10.000000     10.000000     10.000000
#
#          AssessJob5    AssessJob6    AssessJob7    AssessJob8    AssessJob9  \
# count  66985.000000  66985.000000  66985.000000  66985.000000  66985.000000
# mean       3.953243      4.407196      5.673181      4.225200      7.640009
# std        2.520499      2.502069      2.923998      2.507411      2.407457
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        2.000000      2.000000      3.000000      2.000000      6.000000
# 50%        3.000000      4.000000      6.000000      4.000000      8.000000
# 75%        6.000000      6.000000      8.000000      6.000000     10.000000
# max       10.000000     10.000000     10.000000     10.000000     10.000000
#
#        ...  JobEmailPriorities6  JobEmailPriorities7  ConvertedSalary  \
# count  ...          46213.00000         46213.000000     4.770200e+04
# mean   ...              4.97425             4.836388     9.578086e+04
# std    ...              1.86063             1.659844     2.023482e+05
# min    ...              1.00000             1.000000     0.000000e+00
# 25%    ...              4.00000             4.000000     2.384400e+04
# 50%    ...              5.00000             5.000000     5.507500e+04
# 75%    ...              7.00000             6.000000     9.300000e+04
# max    ...              7.00000             7.000000     2.000000e+06
#
#        AdsPriorities1  AdsPriorities2  AdsPriorities3  AdsPriorities4  \
# count    60479.000000    60479.000000    60479.000000    60479.000000
# mean         2.726880        3.805784        3.340945        3.782470
# std          1.881078        1.821323        1.673485        1.844864
# min          1.000000        1.000000        1.000000        1.000000
# 25%          1.000000        2.000000        2.000000        2.000000
# 50%          2.000000        4.000000        3.000000        4.000000
# 75%          4.000000        5.000000        5.000000        5.000000
# max          7.000000        7.000000        7.000000        7.000000
#
#        AdsPriorities5  AdsPriorities6  AdsPriorities7
# count    60479.000000    60479.000000    60479.000000
# mean         4.383604        5.138809        4.821459
# std          1.931746        1.853249        1.874895
# min          1.000000        1.000000        1.000000
# 25%          3.000000        4.000000        3.000000
# 50%          5.000000        6.000000        5.000000
# 75%          6.000000        7.000000        7.000000
# max          7.000000        7.000000        7.000000
#
# [8 rows x 42 columns]

# %%
columns=['Hobby','OpenSource','Country','Employment',\
    'FormalEducation','UndergradMajor','JobSatisfaction','ConvertedSalary']

data=df.get(columns).dropna()
data=data.rename(columns={'ConvertedSalary':'Salary'})
data.head()
# Out:
#   Hobby OpenSource         Country          Employment  \
# 1   Yes        Yes  United Kingdom  Employed full-time
# 4   Yes         No    South Africa  Employed full-time
# 5   Yes         No  United Kingdom  Employed full-time
# 6   Yes        Yes   United States  Employed full-time
# 8   Yes        Yes   United States  Employed full-time
#
#                                      FormalEducation  \
# 1           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4  Some college/university study without earning ...
# 5           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6  Some college/university study without earning ...
# 8  Some college/university study without earning ...
#
#                                       UndergradMajor          JobSatisfaction  \
# 1  A natural science (ex. biology, chemistry, phy...  Moderately dissatisfied
# 4  Computer science, computer engineering, or sof...       Slightly satisfied
# 5  Computer science, computer engineering, or sof...     Moderately satisfied
# 6  Computer science, computer engineering, or sof...       Slightly satisfied
# 8  Fine arts or performing arts (ex. graphic desi...     Moderately satisfied
#
#      Salary
# 1   70841.0
# 4   21426.0
# 5   41671.0
# 6  120000.0
# 8  250000.0

# %%
js_dict = {
    'Extremely dissatisfied':0,
    'Moderately dissatisfied':1,
    'Slightly dissatisfied':2,
    'Neither satisfied nor dissatisfied':3,
    'Slightly satisfied':4,
    'Moderately satisfied':5,
    'Extremely satisfied':6,
}

data['JobSatisfaction']=data['JobSatisfaction'].map(js_dict)

# %%
data = data.replace('Bachelor’s degree (BA, BS, B.Eng., etc.)',"Bachelor")
data = data.replace('Master’s degree (MA, MS, M.Eng., MBA, etc.)',"Master")
data = data.replace('Other doctoral degree (Ph.D, Ed.D., etc.)',"Ph.D")
data = data[data['FormalEducation'].isin(['Bachelor','Master','Ph.D'])]

# %%
countries=data.groupby('Country').size().sort_values()[-3:].index.tolist()
data = data[data['Country'].isin(countries)]

# %%
plt.figure(figsize=(10,8))
data.Salary=data.Salary.map(lambda x: '0-250.000' if x<=250000 else '250.000-1.000.000' if x<=1000000 else '1.000.000+')
data.Salary.hist()
# Out:
# <AxesSubplot:>

# %%
stem=['A natural science (ex. biology, chemistry, physics)',
 'Computer science, computer engineering, or software engineering',
 'Web development or web design',
 'Another engineering discipline (ex. civil, electrical, mechanical)',
 'Mathematics or statistics',
 'Information systems, information technology, or system administration',
]

not_stem=[ 'A social science (ex. anthropology, psychology, political science)',
 'A humanities discipline (ex. literature, history, philosophy)',
 'A business discipline (ex. accounting, finance, marketing)',
 'Fine arts or performing arts (ex. graphic design, music, studio art)',
 'A health science (ex. nursing, pharmacy, radiology)',
]

data=data[data['UndergradMajor'].isin(stem+not_stem)]
data.UndergradMajor=data.UndergradMajor.map(lambda x: 'STEM' if x in stem else 'NOT_STEM')
#'I never declared a major' WHERE DO THEY GO?

# %%
display(data.head())
for col in data.columns: 
    print(col,data[col].unique())
# Out:
#    Hobby OpenSource         Country          Employment FormalEducation  \
# 1    Yes        Yes  United Kingdom  Employed full-time        Bachelor
# 5    Yes         No  United Kingdom  Employed full-time        Bachelor
# 22    No         No  United Kingdom  Employed full-time        Bachelor
# 24   Yes         No           India  Employed full-time          Master
# 27    No         No   United States  Employed full-time        Bachelor
#
#    UndergradMajor  JobSatisfaction    ConvertedSalary
# 1            STEM                1          0-250.000
# 5            STEM                5          0-250.000
# 22           STEM                4          0-250.000
# 24           STEM                5          0-250.000
# 27       NOT_STEM                5  250.000-1.000.000
# Hobby ['Yes' 'No']
# OpenSource ['Yes' 'No']
# Country ['United Kingdom' 'India' 'United States']
# Employment ['Employed full-time' 'Employed part-time'
#  'Independent contractor, freelancer, or self-employed']
# FormalEducation ['Bachelor' 'Master' 'Ph.D']
# UndergradMajor ['STEM' 'NOT_STEM']
# JobSatisfaction [1 5 4 0 6 2 3]
# ConvertedSalary ['0-250.000' '250.000-1.000.000' '1.000.000+']

# %%
def chi2_contingency_mat(data,alpha=None):
    s=data.columns.size
    a = 0
    b = 0
    mat=np.zeros((s,s))
    for i in data.columns:
        for j in data.columns:
            contigency_pct = pd.crosstab(data[i], data[j])
            c, p, dof, expected = chi2_contingency(contigency_pct)
            mat[a][b]=p
            b=b+1
        a = a+1
        b=0
    if alpha:
        mat[mat>=alpha]=1
        mat[mat<alpha]=0
    return mat

# %%
chi2Mat=chi2_contingency_mat(data,0.000005)
plt.figure(figsize=(10,8))
sns.heatmap(chi2Mat,annot=True,xticklabels=data.columns, yticklabels=data.columns)
# Out:
# <AxesSubplot:>

# %%
def getEdges(mat,names=[]):
    result=[]
    l,_=mat.shape
    for i in range(l): 
        for j in range(i+1,l):
            if mat[i,j]==0:
                if len(names)>0:
                    result.append((names[i],names[j]))
                else: result.append((i,j))
    return result    
edges=getEdges(chi2Mat,names=data.columns)
edges
# Out:
# [('Hobby', 'OpenSource'),
#  ('OpenSource', 'Country'),
#  ('OpenSource', 'Employment'),
#  ('OpenSource', 'FormalEducation'),
#  ('OpenSource', 'JobSatisfaction'),
#  ('Country', 'Employment'),
#  ('Country', 'FormalEducation'),
#  ('Country', 'UndergradMajor'),
#  ('Country', 'JobSatisfaction'),
#  ('Country', 'ConvertedSalary'),
#  ('Employment', 'JobSatisfaction'),
#  ('Employment', 'ConvertedSalary'),
#  ('FormalEducation', 'JobSatisfaction'),
#  ('UndergradMajor', 'JobSatisfaction')]

# %%
from pgmpy.models import BayesianNetwork
from pgmpy.estimators import ParameterEstimator,MaximumLikelihoodEstimator

model= BayesianNetwork(edges)
pe = ParameterEstimator(model, data)
model.fit(data, estimator=MaximumLikelihoodEstimator)
for cpd in model.get_cpds():
    print(cpd)

model.get_independencies()
# Out:
# +------------+----------+
# | Hobby(No)  | 0.199923 |
# +------------+----------+
# | Hobby(Yes) | 0.800077 |
# +------------+----------+
# +-----------------+--------------------+---------------------+
# | Hobby           | Hobby(No)          | Hobby(Yes)          |
# +-----------------+--------------------+---------------------+
# | OpenSource(No)  | 0.7966101694915254 | 0.49800223749400674 |
# +-----------------+--------------------+---------------------+
# | OpenSource(Yes) | 0.2033898305084746 | 0.5019977625059933  |
# +-----------------+--------------------+---------------------+
# +-------------------------+-----+---------------------+
# | Hobby                   | ... | Hobby(Yes)          |
# +-------------------------+-----+---------------------+
# | OpenSource              | ... | OpenSource(Yes)     |
# +-------------------------+-----+---------------------+
# | Country(India)          | ... | 0.24212034383954154 |
# +-------------------------+-----+---------------------+
# | Country(United Kingdom) | ... | 0.16841770136899076 |
# +-------------------------+-----+---------------------+
# | Country(United States)  | ... | 0.5894619547914677  |
# +-------------------------+-----+---------------------+
# +-----+------------------------+
# | ... | Country(United States) |
# +-----+------------------------+
# | ... | Hobby(Yes)             |
# +-----+------------------------+
# | ... | OpenSource(Yes)        |
# +-----+------------------------+
# | ... | 0.9362678908992709     |
# +-----+------------------------+
# | ... | 0.011612206319200648   |
# +-----+------------------------+
# | ... | 0.05211990278152849    |
# +-----+------------------------+
# +--------------------+-----+
# | Country            | ... |
# +--------------------+-----+
# | Employment         | ... |
# +--------------------+-----+
# | FormalEducation    | ... |
# +--------------------+-----+
# | Hobby              | ... |
# +--------------------+-----+
# | OpenSource         | ... |
# +--------------------+-----+
# | UndergradMajor     | ... |
# +--------------------+-----+
# | JobSatisfaction(0) | ... |
# +--------------------+-----+
# | JobSatisfaction(1) | ... |
# +--------------------+-----+
# | JobSatisfaction(2) | ... |
# +--------------------+-----+
# | JobSatisfaction(3) | ... |
# +--------------------+-----+
# | JobSatisfaction(4) | ... |
# +--------------------+-----+
# | JobSatisfaction(5) | ... |
# +--------------------+-----+
# | JobSatisfaction(6) | ... |
# +--------------------+-----+
# +---------------------------+-----+
# | Country                   | ... |
# +---------------------------+-----+
# | Employment                | ... |
# +---------------------------+-----+
# | OpenSource                | ... |
# +---------------------------+-----+
# | FormalEducation(Bachelor) | ... |
# +---------------------------+-----+
# | FormalEducation(Master)   | ... |
# +---------------------------+-----+
# | FormalEducation(Ph.D)     | ... |
# +---------------------------+-----+
# +--------------------------+-----+
# | Country                  | ... |
# +--------------------------+-----+
# | Employment               | ... |
# +--------------------------+-----+
# | UndergradMajor(NOT_STEM) | ... |
# +--------------------------+-----+
# | UndergradMajor(STEM)     | ... |
# +--------------------------+-----+
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# (OpenSource ⟂ UndergradMajor | Employment, Country)
# (OpenSource ⟂ UndergradMajor, ConvertedSalary | FormalEducation, Employment, Country)
# (OpenSource ⟂ UndergradMajor | Employment, Hobby, Country)
# (OpenSource ⟂ UndergradMajor | Employment, Country, ConvertedSalary)
# (OpenSource ⟂ ConvertedSalary | FormalEducation, Employment, JobSatisfaction, Country)
# (OpenSource ⟂ ConvertedSalary | FormalEducation, Employment, Country, UndergradMajor)
# (OpenSource ⟂ UndergradMajor, ConvertedSalary | FormalEducation, Employment, Hobby, Country)
# (OpenSource ⟂ UndergradMajor | FormalEducation, Employment, Country, ConvertedSalary)
# (OpenSource ⟂ UndergradMajor | Employment, Hobby, Country, ConvertedSalary)
# (OpenSource ⟂ ConvertedSalary | Employment, UndergradMajor, FormalEducation, JobSatisfaction, Country)
# (OpenSource ⟂ ConvertedSalary | Employment, FormalEducation, JobSatisfaction, Country, Hobby)
# (OpenSource ⟂ ConvertedSalary | Employment, UndergradMajor, FormalEducation, Country, Hobby)
# (OpenSource ⟂ UndergradMajor | Employment, ConvertedSalary, FormalEducation, Country, Hobby)
# (OpenSource ⟂ ConvertedSalary | Employment, UndergradMajor, FormalEducation, JobSatisfaction, Country, Hobby)
# (UndergradMajor ⟂ FormalEducation, Hobby, OpenSource, ConvertedSalary | Employment, Country)
# (UndergradMajor ⟂ Hobby, OpenSource, ConvertedSalary | FormalEducation, Employment, Country)
# (UndergradMajor ⟂ FormalEducation, OpenSource, ConvertedSalary | Employment, Hobby, Country)
# (UndergradMajor ⟂ FormalEducation, Hobby, ConvertedSalary | Employment, OpenSource, Country)
# (UndergradMajor ⟂ FormalEducation, Hobby, OpenSource | Employment, Country, ConvertedSalary)
# (UndergradMajor ⟂ OpenSource, ConvertedSalary | FormalEducation, Employment, Hobby, Country)
# (UndergradMajor ⟂ ConvertedSalary | FormalEducation, Employment, JobSatisfaction, Country)
# (UndergradMajor ⟂ Hobby, ConvertedSalary | FormalEducation, Employment, OpenSource, Country)
# (UndergradMajor ⟂ Hobby, OpenSource | FormalEducation, Employment, Country, ConvertedSalary)
# (UndergradMajor ⟂ FormalEducation, ConvertedSalary | OpenSource, Employment, Hobby, Country)
# (UndergradMajor ⟂ FormalEducation, OpenSource | Employment, Hobby, Country, ConvertedSalary)
# (UndergradMajor ⟂ FormalEducation, Hobby | Employment, OpenSource, Country, ConvertedSalary)
# (UndergradMajor ⟂ ConvertedSalary | Employment, FormalEducation, JobSatisfaction, Country, Hobby)
# (UndergradMajor ⟂ ConvertedSalary | Hobby, Employment, FormalEducation, Country, OpenSource)
# (UndergradMajor ⟂ OpenSource | Employment, ConvertedSalary, FormalEducation, Country, Hobby)
# (UndergradMajor ⟂ ConvertedSalary | Employment, FormalEducation, JobSatisfaction, Country, OpenSource)
# (UndergradMajor ⟂ Hobby | Employment, ConvertedSalary, FormalEducation, Country, OpenSource)
# (UndergradMajor ⟂ FormalEducation | Hobby, Employment, ConvertedSalary, Country, OpenSource)
# (UndergradMajor ⟂ ConvertedSalary | Employment, OpenSource, FormalEducation, JobSatisfaction, Country, Hobby)
# (ConvertedSalary ⟂ UndergradMajor | Employment, Country)
# (ConvertedSalary ⟂ Hobby, JobSatisfaction, OpenSource, UndergradMajor | FormalEducation, Employment, Country)
# (ConvertedSalary ⟂ UndergradMajor | Employment, Hobby, Country)
# (ConvertedSalary ⟂ Hobby, UndergradMajor | Employment, OpenSource, Country)
# (ConvertedSalary ⟂ JobSatisfaction, OpenSource, UndergradMajor | FormalEducation, Employment, Hobby, Country)
# (ConvertedSalary ⟂ Hobby, OpenSource, UndergradMajor | FormalEducation, Employment, JobSatisfaction, Country)
# (ConvertedSalary ⟂ JobSatisfaction, Hobby, OpenSource | FormalEducation, Employment, Country, UndergradMajor)
# (ConvertedSalary ⟂ JobSatisfaction, Hobby, UndergradMajor | FormalEducation, Employment, OpenSource, Country)
# (ConvertedSalary ⟂ UndergradMajor | OpenSource, Employment, Hobby, Country)
# (ConvertedSalary ⟂ Hobby | OpenSource, Employment, Country, UndergradMajor)
# (ConvertedSalary ⟂ OpenSource, UndergradMajor | Employment, FormalEducation, JobSatisfaction, Country, Hobby)
# (ConvertedSalary ⟂ JobSatisfaction, OpenSource | Employment, UndergradMajor, FormalEducation, Country, Hobby)
# (ConvertedSalary ⟂ JobSatisfaction, UndergradMajor | Hobby, Employment, FormalEducation, Country, OpenSource)
# (ConvertedSalary ⟂ Hobby, OpenSource | Employment, UndergradMajor, FormalEducation, JobSatisfaction, Country)
# (ConvertedSalary ⟂ Hobby, UndergradMajor | Employment, FormalEducation, JobSatisfaction, Country, OpenSource)
# (ConvertedSalary ⟂ JobSatisfaction, Hobby | Employment, UndergradMajor, FormalEducation, Country, OpenSource)
# (ConvertedSalary ⟂ OpenSource | Employment, UndergradMajor, FormalEducation, JobSatisfaction, Country, Hobby)
# (ConvertedSalary ⟂ UndergradMajor | Employment, OpenSource, FormalEducation, JobSatisfaction, Country, Hobby)
# (ConvertedSalary ⟂ JobSatisfaction | Employment, UndergradMajor, OpenSource, FormalEducation, Country, Hobby)
# (ConvertedSalary ⟂ Hobby | Employment, UndergradMajor, FormalEducation, JobSatisfaction, Country, OpenSource)
# (FormalEducation ⟂ UndergradMajor | Employment, Country)
# (FormalEducation ⟂ UndergradMajor | Employment, Hobby, Country)
# (FormalEducation ⟂ Hobby, UndergradMajor | Employment, OpenSource, Country)
# (FormalEducation ⟂ UndergradMajor | Employment, Country, ConvertedSalary)
# (FormalEducation ⟂ UndergradMajor | OpenSource, Employment, Hobby, Country)
# (FormalEducation ⟂ UndergradMajor | Employment, Hobby, Country, ConvertedSalary)
# (FormalEducation ⟂ Hobby | OpenSource, Employment, Country, UndergradMajor)
# (FormalEducation ⟂ Hobby, UndergradMajor | Employment, OpenSource, Country, ConvertedSalary)
# (FormalEducation ⟂ UndergradMajor | Hobby, Employment, ConvertedSalary, Country, OpenSource)
# (FormalEducation ⟂ Hobby | Employment, UndergradMajor, ConvertedSalary, Country, OpenSource)
# (JobSatisfaction ⟂ ConvertedSalary | FormalEducation, Employment, Country)
# (JobSatisfaction ⟂ ConvertedSalary | FormalEducation, Employment, Hobby, Country)
# (JobSatisfaction ⟂ ConvertedSalary | FormalEducation, Employment, Country, UndergradMajor)
# (JobSatisfaction ⟂ ConvertedSalary | FormalEducation, Employment, OpenSource, Country)
# (JobSatisfaction ⟂ ConvertedSalary | Employment, UndergradMajor, FormalEducation, Country, Hobby)
# (JobSatisfaction ⟂ ConvertedSalary | Hobby, Employment, FormalEducation, Country, OpenSource)
# (JobSatisfaction ⟂ ConvertedSalary | Employment, UndergradMajor, FormalEducation, Country, OpenSource)
# (JobSatisfaction ⟂ ConvertedSalary | Employment, UndergradMajor, OpenSource, FormalEducation, Country, Hobby)
# (Hobby ⟂ UndergradMajor | Employment, Country)
# (Hobby ⟂ UndergradMajor, ConvertedSalary | FormalEducation, Employment, Country)
# (Hobby ⟂ FormalEducation, UndergradMajor, ConvertedSalary | Employment, OpenSource, Country)
# (Hobby ⟂ UndergradMajor | Employment, Country, ConvertedSalary)
# (Hobby ⟂ ConvertedSalary | FormalEducation, Employment, JobSatisfaction, Country)
# (Hobby ⟂ ConvertedSalary | FormalEducation, Employment, Country, UndergradMajor)
# (Hobby ⟂ UndergradMajor, ConvertedSalary | FormalEducation, Employment, OpenSource, Country)
# (Hobby ⟂ UndergradMajor | FormalEducation, Employment, Country, ConvertedSalary)
# (Hobby ⟂ FormalEducation, ConvertedSalary | OpenSource, Employment, Country, UndergradMajor)
# (Hobby ⟂ FormalEducation, UndergradMajor | Employment, OpenSource, Country, ConvertedSalary)
# (Hobby ⟂ ConvertedSalary | Employment, UndergradMajor, FormalEducation, JobSatisfaction, Country)
# (Hobby ⟂ ConvertedSalary | Employment, FormalEducation, JobSatisfaction, Country, OpenSource)
# (Hobby ⟂ ConvertedSalary | Employment, UndergradMajor, FormalEducation, Country, OpenSource)
# (Hobby ⟂ UndergradMajor | Employment, ConvertedSalary, FormalEducation, Country, OpenSource)
# (Hobby ⟂ FormalEducation | Employment, UndergradMajor, ConvertedSalary, Country, OpenSource)
# (Hobby ⟂ ConvertedSalary | Employment, UndergradMajor, FormalEducation, JobSatisfaction, Country, OpenSource)

# %%
model.check_model()
# Out:
# True
